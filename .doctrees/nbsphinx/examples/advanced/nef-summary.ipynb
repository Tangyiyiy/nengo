# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="726633000" href="javascript:toggle_input_726633000()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_726633000;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_726633000 = document.getElementById("726633000");
#                 var cell = link_726633000;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_726633000;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_726633000 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_726633000 = cell.previousElementSibling;
#                 }
#                 input_726633000.style.display = "none"; // hide
#
#                 toggle_input_726633000 = function() {
#                     if (input_726633000.style.display == "none") {
#                         input_726633000.style.display = ""; // show
#                         link_726633000.innerHTML = "Hide Input";
#                     } else {
#                         input_726633000.style.display = "none"; // hide
#                         link_726633000.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_726633000 = $("a[id='726633000']");
#                 var cell_726633000 = link_726633000.parents("div.cell:first");
#                 if (cell_726633000.length == 0) {
#                     cell_726633000 = link_726633000.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_726633000 = cell_726633000.children("div.input");
#                 if (input_726633000.length == 0) {
#                     input_726633000 = cell_726633000.prev("div.nbinput");
#                 }
#                 input_726633000.hide();
#
#                 toggle_input_726633000 = function() {
#                     if (input_726633000.is(':hidden')) {
#                         input_726633000.slideDown();
#                         link_726633000[0].innerHTML = "Hide Input";
#                     } else {
#                         input_726633000.slideUp();
#                         link_726633000[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="1412609489" href="javascript:toggle_input_1412609489()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1412609489;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1412609489 = document.getElementById("1412609489");
#                 var cell = link_1412609489;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1412609489;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1412609489 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1412609489 = cell.previousElementSibling;
#                 }
#                 input_1412609489.style.display = "none"; // hide
#
#                 toggle_input_1412609489 = function() {
#                     if (input_1412609489.style.display == "none") {
#                         input_1412609489.style.display = ""; // show
#                         link_1412609489.innerHTML = "Hide Input";
#                     } else {
#                         input_1412609489.style.display = "none"; // hide
#                         link_1412609489.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1412609489 = $("a[id='1412609489']");
#                 var cell_1412609489 = link_1412609489.parents("div.cell:first");
#                 if (cell_1412609489.length == 0) {
#                     cell_1412609489 = link_1412609489.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1412609489 = cell_1412609489.children("div.input");
#                 if (input_1412609489.length == 0) {
#                     input_1412609489 = cell_1412609489.prev("div.nbinput");
#                 }
#                 input_1412609489.hide();
#
#                 toggle_input_1412609489 = function() {
#                     if (input_1412609489.is(':hidden')) {
#                         input_1412609489.slideDown();
#                         link_1412609489[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1412609489.slideUp();
#                         link_1412609489[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="794712589" href="javascript:toggle_input_794712589()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_794712589;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_794712589 = document.getElementById("794712589");
#                 var cell = link_794712589;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_794712589;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_794712589 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_794712589 = cell.previousElementSibling;
#                 }
#                 input_794712589.style.display = "none"; // hide
#
#                 toggle_input_794712589 = function() {
#                     if (input_794712589.style.display == "none") {
#                         input_794712589.style.display = ""; // show
#                         link_794712589.innerHTML = "Hide Input";
#                     } else {
#                         input_794712589.style.display = "none"; // hide
#                         link_794712589.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_794712589 = $("a[id='794712589']");
#                 var cell_794712589 = link_794712589.parents("div.cell:first");
#                 if (cell_794712589.length == 0) {
#                     cell_794712589 = link_794712589.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_794712589 = cell_794712589.children("div.input");
#                 if (input_794712589.length == 0) {
#                     input_794712589 = cell_794712589.prev("div.nbinput");
#                 }
#                 input_794712589.hide();
#
#                 toggle_input_794712589 = function() {
#                     if (input_794712589.is(':hidden')) {
#                         input_794712589.slideDown();
#                         link_794712589[0].innerHTML = "Hide Input";
#                     } else {
#                         input_794712589.slideUp();
#                         link_794712589[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1646192922" href="javascript:toggle_input_1646192922()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1646192922;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1646192922 = document.getElementById("1646192922");
#                 var cell = link_1646192922;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1646192922;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1646192922 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1646192922 = cell.previousElementSibling;
#                 }
#                 input_1646192922.style.display = "none"; // hide
#
#                 toggle_input_1646192922 = function() {
#                     if (input_1646192922.style.display == "none") {
#                         input_1646192922.style.display = ""; // show
#                         link_1646192922.innerHTML = "Hide Input";
#                     } else {
#                         input_1646192922.style.display = "none"; // hide
#                         link_1646192922.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1646192922 = $("a[id='1646192922']");
#                 var cell_1646192922 = link_1646192922.parents("div.cell:first");
#                 if (cell_1646192922.length == 0) {
#                     cell_1646192922 = link_1646192922.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1646192922 = cell_1646192922.children("div.input");
#                 if (input_1646192922.length == 0) {
#                     input_1646192922 = cell_1646192922.prev("div.nbinput");
#                 }
#                 input_1646192922.hide();
#
#                 toggle_input_1646192922 = function() {
#                     if (input_1646192922.is(':hidden')) {
#                         input_1646192922.slideDown();
#                         link_1646192922[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1646192922.slideUp();
#                         link_1646192922[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="2035996530" href="javascript:toggle_input_2035996530()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2035996530;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2035996530 = document.getElementById("2035996530");
#                 var cell = link_2035996530;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2035996530;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2035996530 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2035996530 = cell.previousElementSibling;
#                 }
#                 input_2035996530.style.display = "none"; // hide
#
#                 toggle_input_2035996530 = function() {
#                     if (input_2035996530.style.display == "none") {
#                         input_2035996530.style.display = ""; // show
#                         link_2035996530.innerHTML = "Hide Input";
#                     } else {
#                         input_2035996530.style.display = "none"; // hide
#                         link_2035996530.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2035996530 = $("a[id='2035996530']");
#                 var cell_2035996530 = link_2035996530.parents("div.cell:first");
#                 if (cell_2035996530.length == 0) {
#                     cell_2035996530 = link_2035996530.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2035996530 = cell_2035996530.children("div.input");
#                 if (input_2035996530.length == 0) {
#                     input_2035996530 = cell_2035996530.prev("div.nbinput");
#                 }
#                 input_2035996530.hide();
#
#                 toggle_input_2035996530 = function() {
#                     if (input_2035996530.is(':hidden')) {
#                         input_2035996530.slideDown();
#                         link_2035996530[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2035996530.slideUp();
#                         link_2035996530[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="310647867" href="javascript:toggle_input_310647867()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_310647867;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_310647867 = document.getElementById("310647867");
#                 var cell = link_310647867;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_310647867;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_310647867 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_310647867 = cell.previousElementSibling;
#                 }
#                 input_310647867.style.display = "none"; // hide
#
#                 toggle_input_310647867 = function() {
#                     if (input_310647867.style.display == "none") {
#                         input_310647867.style.display = ""; // show
#                         link_310647867.innerHTML = "Hide Input";
#                     } else {
#                         input_310647867.style.display = "none"; // hide
#                         link_310647867.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_310647867 = $("a[id='310647867']");
#                 var cell_310647867 = link_310647867.parents("div.cell:first");
#                 if (cell_310647867.length == 0) {
#                     cell_310647867 = link_310647867.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_310647867 = cell_310647867.children("div.input");
#                 if (input_310647867.length == 0) {
#                     input_310647867 = cell_310647867.prev("div.nbinput");
#                 }
#                 input_310647867.hide();
#
#                 toggle_input_310647867 = function() {
#                     if (input_310647867.is(':hidden')) {
#                         input_310647867.slideDown();
#                         link_310647867[0].innerHTML = "Hide Input";
#                     } else {
#                         input_310647867.slideUp();
#                         link_310647867[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1351869201" href="javascript:toggle_input_1351869201()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1351869201;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1351869201 = document.getElementById("1351869201");
#                 var cell = link_1351869201;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1351869201;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1351869201 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1351869201 = cell.previousElementSibling;
#                 }
#                 input_1351869201.style.display = "none"; // hide
#
#                 toggle_input_1351869201 = function() {
#                     if (input_1351869201.style.display == "none") {
#                         input_1351869201.style.display = ""; // show
#                         link_1351869201.innerHTML = "Hide Input";
#                     } else {
#                         input_1351869201.style.display = "none"; // hide
#                         link_1351869201.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1351869201 = $("a[id='1351869201']");
#                 var cell_1351869201 = link_1351869201.parents("div.cell:first");
#                 if (cell_1351869201.length == 0) {
#                     cell_1351869201 = link_1351869201.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1351869201 = cell_1351869201.children("div.input");
#                 if (input_1351869201.length == 0) {
#                     input_1351869201 = cell_1351869201.prev("div.nbinput");
#                 }
#                 input_1351869201.hide();
#
#                 toggle_input_1351869201 = function() {
#                     if (input_1351869201.is(':hidden')) {
#                         input_1351869201.slideDown();
#                         link_1351869201[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1351869201.slideUp();
#                         link_1351869201[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1191820576" href="javascript:toggle_input_1191820576()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1191820576;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1191820576 = document.getElementById("1191820576");
#                 var cell = link_1191820576;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1191820576;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1191820576 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1191820576 = cell.previousElementSibling;
#                 }
#                 input_1191820576.style.display = "none"; // hide
#
#                 toggle_input_1191820576 = function() {
#                     if (input_1191820576.style.display == "none") {
#                         input_1191820576.style.display = ""; // show
#                         link_1191820576.innerHTML = "Hide Input";
#                     } else {
#                         input_1191820576.style.display = "none"; // hide
#                         link_1191820576.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1191820576 = $("a[id='1191820576']");
#                 var cell_1191820576 = link_1191820576.parents("div.cell:first");
#                 if (cell_1191820576.length == 0) {
#                     cell_1191820576 = link_1191820576.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1191820576 = cell_1191820576.children("div.input");
#                 if (input_1191820576.length == 0) {
#                     input_1191820576 = cell_1191820576.prev("div.nbinput");
#                 }
#                 input_1191820576.hide();
#
#                 toggle_input_1191820576 = function() {
#                     if (input_1191820576.is(':hidden')) {
#                         input_1191820576.slideDown();
#                         link_1191820576[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1191820576.slideUp();
#                         link_1191820576[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1682540539" href="javascript:toggle_input_1682540539()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1682540539;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1682540539 = document.getElementById("1682540539");
#                 var cell = link_1682540539;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1682540539;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1682540539 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1682540539 = cell.previousElementSibling;
#                 }
#                 input_1682540539.style.display = "none"; // hide
#
#                 toggle_input_1682540539 = function() {
#                     if (input_1682540539.style.display == "none") {
#                         input_1682540539.style.display = ""; // show
#                         link_1682540539.innerHTML = "Hide Input";
#                     } else {
#                         input_1682540539.style.display = "none"; // hide
#                         link_1682540539.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1682540539 = $("a[id='1682540539']");
#                 var cell_1682540539 = link_1682540539.parents("div.cell:first");
#                 if (cell_1682540539.length == 0) {
#                     cell_1682540539 = link_1682540539.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1682540539 = cell_1682540539.children("div.input");
#                 if (input_1682540539.length == 0) {
#                     input_1682540539 = cell_1682540539.prev("div.nbinput");
#                 }
#                 input_1682540539.hide();
#
#                 toggle_input_1682540539 = function() {
#                     if (input_1682540539.is(':hidden')) {
#                         input_1682540539.slideDown();
#                         link_1682540539[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1682540539.slideUp();
#                         link_1682540539[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="554777821" href="javascript:toggle_input_554777821()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_554777821;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_554777821 = document.getElementById("554777821");
#                 var cell = link_554777821;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_554777821;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_554777821 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_554777821 = cell.previousElementSibling;
#                 }
#                 input_554777821.style.display = "none"; // hide
#
#                 toggle_input_554777821 = function() {
#                     if (input_554777821.style.display == "none") {
#                         input_554777821.style.display = ""; // show
#                         link_554777821.innerHTML = "Hide Input";
#                     } else {
#                         input_554777821.style.display = "none"; // hide
#                         link_554777821.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_554777821 = $("a[id='554777821']");
#                 var cell_554777821 = link_554777821.parents("div.cell:first");
#                 if (cell_554777821.length == 0) {
#                     cell_554777821 = link_554777821.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_554777821 = cell_554777821.children("div.input");
#                 if (input_554777821.length == 0) {
#                     input_554777821 = cell_554777821.prev("div.nbinput");
#                 }
#                 input_554777821.hide();
#
#                 toggle_input_554777821 = function() {
#                     if (input_554777821.is(':hidden')) {
#                         input_554777821.slideDown();
#                         link_554777821[0].innerHTML = "Hide Input";
#                     } else {
#                         input_554777821.slideUp();
#                         link_554777821[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1765550238" href="javascript:toggle_input_1765550238()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1765550238;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1765550238 = document.getElementById("1765550238");
#                 var cell = link_1765550238;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1765550238;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1765550238 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1765550238 = cell.previousElementSibling;
#                 }
#                 input_1765550238.style.display = "none"; // hide
#
#                 toggle_input_1765550238 = function() {
#                     if (input_1765550238.style.display == "none") {
#                         input_1765550238.style.display = ""; // show
#                         link_1765550238.innerHTML = "Hide Input";
#                     } else {
#                         input_1765550238.style.display = "none"; // hide
#                         link_1765550238.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1765550238 = $("a[id='1765550238']");
#                 var cell_1765550238 = link_1765550238.parents("div.cell:first");
#                 if (cell_1765550238.length == 0) {
#                     cell_1765550238 = link_1765550238.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1765550238 = cell_1765550238.children("div.input");
#                 if (input_1765550238.length == 0) {
#                     input_1765550238 = cell_1765550238.prev("div.nbinput");
#                 }
#                 input_1765550238.hide();
#
#                 toggle_input_1765550238 = function() {
#                     if (input_1765550238.is(':hidden')) {
#                         input_1765550238.slideDown();
#                         link_1765550238[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1765550238.slideUp();
#                         link_1765550238[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="467509872" href="javascript:toggle_input_467509872()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_467509872;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_467509872 = document.getElementById("467509872");
#                 var cell = link_467509872;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_467509872;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_467509872 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_467509872 = cell.previousElementSibling;
#                 }
#                 input_467509872.style.display = "none"; // hide
#
#                 toggle_input_467509872 = function() {
#                     if (input_467509872.style.display == "none") {
#                         input_467509872.style.display = ""; // show
#                         link_467509872.innerHTML = "Hide Input";
#                     } else {
#                         input_467509872.style.display = "none"; // hide
#                         link_467509872.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_467509872 = $("a[id='467509872']");
#                 var cell_467509872 = link_467509872.parents("div.cell:first");
#                 if (cell_467509872.length == 0) {
#                     cell_467509872 = link_467509872.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_467509872 = cell_467509872.children("div.input");
#                 if (input_467509872.length == 0) {
#                     input_467509872 = cell_467509872.prev("div.nbinput");
#                 }
#                 input_467509872.hide();
#
#                 toggle_input_467509872 = function() {
#                     if (input_467509872.is(':hidden')) {
#                         input_467509872.slideDown();
#                         link_467509872[0].innerHTML = "Hide Input";
#                     } else {
#                         input_467509872.slideUp();
#                         link_467509872[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="457990204" href="javascript:toggle_input_457990204()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_457990204;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_457990204 = document.getElementById("457990204");
#                 var cell = link_457990204;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_457990204;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_457990204 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_457990204 = cell.previousElementSibling;
#                 }
#                 input_457990204.style.display = "none"; // hide
#
#                 toggle_input_457990204 = function() {
#                     if (input_457990204.style.display == "none") {
#                         input_457990204.style.display = ""; // show
#                         link_457990204.innerHTML = "Hide Input";
#                     } else {
#                         input_457990204.style.display = "none"; // hide
#                         link_457990204.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_457990204 = $("a[id='457990204']");
#                 var cell_457990204 = link_457990204.parents("div.cell:first");
#                 if (cell_457990204.length == 0) {
#                     cell_457990204 = link_457990204.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_457990204 = cell_457990204.children("div.input");
#                 if (input_457990204.length == 0) {
#                     input_457990204 = cell_457990204.prev("div.nbinput");
#                 }
#                 input_457990204.hide();
#
#                 toggle_input_457990204 = function() {
#                     if (input_457990204.is(':hidden')) {
#                         input_457990204.slideDown();
#                         link_457990204[0].innerHTML = "Hide Input";
#                     } else {
#                         input_457990204.slideUp();
#                         link_457990204[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
